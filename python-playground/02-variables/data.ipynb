# %%
print("Hello World")
print("Mera naam Python h")
print("Python Ai k lie best h")
# Out:
# Hello World
# Mera naam Python h
# Python Ai k lie best h

# %%
#python vs other languages
num = [1,2,3,4,5]
print(sum(num))
# this code consites of two line 
#python readability 
fruits = ['apple', 'orange', 'banana', 'lichi']
for fruit in fruits:
    print("the fruit is",fruit)
# the could be written in single line also
print([fr.upper() for fr in fruits])
# Out:
# 15
# the fruit is apple
# the fruit is orange
# the fruit is banana
# the fruit is lichi
# ['APPLE', 'ORANGE', 'BANANA', 'LICHI']

# %%
x = 10
y = 2

print("add", x + y)
print("multiply", x * y)
print("divide", x / y)
print("subtract", x - y)
print("reminder", x % y)
print("floor division", x // y)
print("Power", x ** y)
# Out:
# add 12
# multiply 20
# divide 5.0
# subtract 8
# reminder 0
# floor division 5
# Power 100

# %%
import random

questions = [
    "Python kya hai?",
    "AI kya hai?",
    "Main kya seekh raha hoon?"
]

answers = [
    "Python ek powerful programming language hai!",
    "AI matlab Artificial Intelligence — machines ko smart banana!",
    "Tum Python se AI Agents banana seekh rahe ho!"
]

i = random.randint(0,2)
print(f"Questions {questions[i]}")
print(f"Answer {answers[i]}")
# Out:
# Questions Main kya seekh raha hoon?
# Answer Tum Python se AI Agents banana seekh rahe ho!
